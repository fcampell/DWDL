# %%
import pandas as pd


df = pd.read_parquet("/Users/fadricampell/Downloads/V1_facade_visibility.parquet")

# %%
df.size
# Out:
# 14559195

# %%
import geopandas as gpd

df_pk= gpd.read_parquet("/Users/fadricampell/Downloads/V1_facade_visibility.parquet")

# %%
df_pk.length
# Out:
# 0         179.743786
# 1         183.315097
# 2         179.741841
# 3         183.314634
# 4         260.793913
#              ...
# 415972    173.245237
# 415973    221.028913
# 415974    192.680105
# 415975    196.547018
# 415976    173.977188
# Length: 415977, dtype: float64

# %%
df_gpkg = gpd.read_file("/Users/fadricampell/Downloads/V1_facade_visibility.gpkg", driver="GPKG")

# %%
df_gpkg.
# Out:
# 14559195

# %%
df_vbz = pd.read_parquet("/Users/fadricampell/Documents/HSLU/Modules/DWDL/DWDL/AWS/containers/local_bucket/gold/vbz_flows/V1_vbz_flows_hourly_flows_table.parquet")

df_vbz_edges = gpd.read_parquet("/Users/fadricampell/Documents/HSLU/Modules/DWDL/DWDL/AWS/containers/local_bucket/gold/vbz_flows/V1_vbz_edges.parquet")

# %%
df_vbz.columns
# Out:
# Index(['Haltestellen_Id', 'Nach_Hst_Id', 'hour', 'flow_besetzung', 'n_runs'], dtype='object')

# %%
df_vbz_edges.columns
# Out:
# Index(['Haltestellen_Id', 'Nach_Hst_Id', 'geometry'], dtype='object')
